# %%
# !python --version
# !pip install pixellib
# !ls /usr/local/lib/python3.10/dist-packages/pixellib/
# Out:
# Python 3.10.12
# Requirement already satisfied: pixellib in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pixellib) (11.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.24.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from pixellib) (4.9.0.80)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.8.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.4.0)
# Requirement already satisfied: labelme2coco in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.2.6)
# Requirement already satisfied: imantics in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.12)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.0.11)
# Requirement already satisfied: pyQt5 in /usr/local/lib/python3.10/dist-packages (from pixellib) (5.15.11)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.5.post20221221)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.10)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pixellib) (2.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.1.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from pixellib) (2.5.0)
# Requirement already satisfied: yacs in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pixellib) (4.66.6)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pixellib) (1.0.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.0.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.6)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.10/dist-packages (from pixellib) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from pixellib) (24.10.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore->pixellib) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pixellib) (6.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->pixellib) (3.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from imantics->pixellib) (5.3.0)
# Requirement already satisfied: xmljson in /usr/local/lib/python3.10/dist-packages (from imantics->pixellib) (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (1.13.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (2.36.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (2.0.6)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (0.4)
# Requirement already satisfied: sahi>=0.8.19 in /usr/local/lib/python3.10/dist-packages (from labelme2coco->pixellib) (0.11.19)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from labelme2coco->pixellib) (4.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (2.8.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /usr/local/lib/python3.10/dist-packages (from pyQt5->pixellib) (12.16.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /usr/local/lib/python3.10/dist-packages (from pyQt5->pixellib) (5.15.15)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.22.3)
# Requirement already satisfied: pybboxes==0.1.6 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.1.6)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.7.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (3.1.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2024.8.30)
# custom_train  __init__.py  instance  __pycache__  semantic  torchbackend  tune_bg

# %%
import os
import fileinput

# Define the path to the file that needs to be modified
FILE_PATH = "/usr/local/lib/python3.10/dist-packages/pixellib/semantic/deeplab.py"

# Define the old and new strings that need to be replaced
OLD_STRING = "tensorflow.python.keras"
NEW_STRING = "tensorflow.keras"

# Use fileinput to replace the old string with the new string in the file
for line in fileinput.input(FILE_PATH, inplace=True):
    print(line.replace(OLD_STRING, NEW_STRING), end='')

# Define the old and new strings that need to be replaced
# This handles model loading errors
OLD_STRING = "tensorflow.keras.utils.layer_utils import get_source_inputs"
NEW_STRING = "tensorflow.python.keras.utils.layer_utils import get_source_inputs"

# Use fileinput to replace the old string with the new string in the file
for line in fileinput.input(FILE_PATH, inplace=True):
    print(line.replace(OLD_STRING, NEW_STRING), end='')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)

cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# Data normalization
x_train = x_train/255
x_test = x_test/255

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])

plot_history(history)


# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()


inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Flatten()(net)
net = Dense(128, activation='relu')(net)
net = BatchNormalization()(net)
net = Dropout(0.5)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

plot_history(history)


# Compute the labels and the predictions as sparse values
y_true = y_test
y_pred = model.predict(x_test).argmax(axis=-1)

# Compute and print the accuracy for each class
for class_id in range(num_classes):
    acc = np.mean(y_pred[y_true == class_id] == class_id)
    print(f'Class {class_id} accuracy: {acc}')

# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])

# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = np.random.randint(0, x_test.shape[0])
    # Show the results
    plt.subplot(3, 5, ii+1)
    plt.imshow(x_test[idx, ...], cmap='gray')
    plt.title(f'True: {y_test[idx]} | Pred: {y_pred[idx]}')
    plt.axis('off')

plt.show()
# Out:
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8278 - loss: 0.4913 - val_accuracy: 0.8817 - val_loss: 0.3287
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9030 - loss: 0.2735 - val_accuracy: 0.8888 - val_loss: 0.3092
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9196 - loss: 0.2247 - val_accuracy: 0.8929 - val_loss: 0.3050
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9319 - loss: 0.1889 - val_accuracy: 0.8933 - val_loss: 0.3137
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9422 - loss: 0.1624 - val_accuracy: 0.8949 - val_loss: 0.3367
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9503 - loss: 0.1398 - val_accuracy: 0.8904 - val_loss: 0.3759
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9574 - loss: 0.1217 - val_accuracy: 0.8878 - val_loss: 0.4018
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9594 - loss: 0.1134 - val_accuracy: 0.8894 - val_loss: 0.4282
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9647 - loss: 0.0993 - val_accuracy: 0.8875 - val_loss: 0.4580
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9689 - loss: 0.0879 - val_accuracy: 0.8896 - val_loss: 0.4934
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9719 - loss: 0.0798 - val_accuracy: 0.8842 - val_loss: 0.5403
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9733 - loss: 0.0754 - val_accuracy: 0.8839 - val_loss: 0.5637
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9752 - loss: 0.0671 - val_accuracy: 0.8879 - val_loss: 0.5708
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9786 - loss: 0.0619 - val_accuracy: 0.8810 - val_loss: 0.6367
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9768 - loss: 0.0623 - val_accuracy: 0.8716 - val_loss: 0.7213
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9779 - loss: 0.0594 - val_accuracy: 0.8838 - val_loss: 0.7026
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9800 - loss: 0.0544 - val_accuracy: 0.8827 - val_loss: 0.7125
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9824 - loss: 0.0481 - val_accuracy: 0.8793 - val_loss: 0.7607
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9841 - loss: 0.0438 - val_accuracy: 0.8771 - val_loss: 0.7868
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9853 - loss: 0.0417 - val_accuracy: 0.8762 - val_loss: 0.8259
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9838 - loss: 0.0431 - val_accuracy: 0.8747 - val_loss: 0.8451
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9843 - loss: 0.0441 - val_accuracy: 0.8752 - val_loss: 0.8637
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9852 - loss: 0.0395 - val_accuracy: 0.8797 - val_loss: 0.8722
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9853 - loss: 0.0393 - val_accuracy: 0.8771 - val_loss: 0.9033
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9853 - loss: 0.0404 - val_accuracy: 0.8793 - val_loss: 0.9248
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9875 - loss: 0.0344 - val_accuracy: 0.8782 - val_loss: 0.9474
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9882 - loss: 0.0322 - val_accuracy: 0.8805 - val_loss: 0.9760
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9889 - loss: 0.0304 - val_accuracy: 0.8768 - val_loss: 0.9773
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9881 - loss: 0.0325 - val_accuracy: 0.8783 - val_loss: 1.0037
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9883 - loss: 0.0332 - val_accuracy: 0.8814 - val_loss: 1.0177
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9887 - loss: 0.0313 - val_accuracy: 0.8820 - val_loss: 1.0435
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9905 - loss: 0.0268 - val_accuracy: 0.8806 - val_loss: 1.0609
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9891 - loss: 0.0310 - val_accuracy: 0.8827 - val_loss: 1.0767
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9892 - loss: 0.0301 - val_accuracy: 0.8836 - val_loss: 1.1049
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9903 - loss: 0.0248 - val_accuracy: 0.8815 - val_loss: 1.1335
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9917 - loss: 0.0224 - val_accuracy: 0.8783 - val_loss: 1.1757
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9915 - loss: 0.0244 - val_accuracy: 0.8795 - val_loss: 1.1360
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9923 - loss: 0.0215 - val_accuracy: 0.8843 - val_loss: 1.1322
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9919 - loss: 0.0224 - val_accuracy: 0.8807 - val_loss: 1.1635
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9927 - loss: 0.0202 - val_accuracy: 0.8831 - val_loss: 1.2034
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9918 - loss: 0.0232 - val_accuracy: 0.8821 - val_loss: 1.1839
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9925 - loss: 0.0221 - val_accuracy: 0.8816 - val_loss: 1.2005
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9943 - loss: 0.0164 - val_accuracy: 0.8821 - val_loss: 1.2050
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9932 - loss: 0.0193 - val_accuracy: 0.8817 - val_loss: 1.3054
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9936 - loss: 0.0184 - val_accuracy: 0.8815 - val_loss: 1.2770
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9924 - loss: 0.0195 - val_accuracy: 0.8826 - val_loss: 1.2816
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9925 - loss: 0.0216 - val_accuracy: 0.8797 - val_loss: 1.2852
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9948 - loss: 0.0143 - val_accuracy: 0.8784 - val_loss: 1.2618
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9929 - loss: 0.0190 - val_accuracy: 0.8808 - val_loss: 1.2946
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9940 - loss: 0.0178 - val_accuracy: 0.8826 - val_loss: 1.2981
# Train Acc      0.9940000176429749
# Validation Acc 0.8826000094413757
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 3136)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │         401,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 422,538 (1.61 MB)
#  Trainable params: 422,090 (1.61 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.7748 - loss: 0.6550 - val_accuracy: 0.8721 - val_loss: 0.3459
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8765 - loss: 0.3453 - val_accuracy: 0.8965 - val_loss: 0.2866
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8930 - loss: 0.2996 - val_accuracy: 0.8989 - val_loss: 0.2823
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9001 - loss: 0.2749 - val_accuracy: 0.9090 - val_loss: 0.2556
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9049 - loss: 0.2607 - val_accuracy: 0.9108 - val_loss: 0.2552
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9087 - loss: 0.2515 - val_accuracy: 0.9133 - val_loss: 0.2726
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9117 - loss: 0.2424 - val_accuracy: 0.8571 - val_loss: 0.4383
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9136 - loss: 0.2298 - val_accuracy: 0.9057 - val_loss: 0.2611
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9180 - loss: 0.2213 - val_accuracy: 0.9087 - val_loss: 0.2577
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9193 - loss: 0.2173 - val_accuracy: 0.8735 - val_loss: 0.4076
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9235 - loss: 0.2080 - val_accuracy: 0.8918 - val_loss: 0.3091
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9262 - loss: 0.1992 - val_accuracy: 0.9248 - val_loss: 0.2175
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9282 - loss: 0.1970 - val_accuracy: 0.9241 - val_loss: 0.2164
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9261 - loss: 0.1956 - val_accuracy: 0.9234 - val_loss: 0.2215
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9317 - loss: 0.1885 - val_accuracy: 0.9267 - val_loss: 0.2159
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9321 - loss: 0.1827 - val_accuracy: 0.9262 - val_loss: 0.2117
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9350 - loss: 0.1763 - val_accuracy: 0.9247 - val_loss: 0.2214
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9347 - loss: 0.1749 - val_accuracy: 0.9169 - val_loss: 0.2470
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9345 - loss: 0.1732 - val_accuracy: 0.9231 - val_loss: 0.2339
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9373 - loss: 0.1714 - val_accuracy: 0.9233 - val_loss: 0.2265
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9385 - loss: 0.1653 - val_accuracy: 0.9209 - val_loss: 0.2454
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9387 - loss: 0.1630 - val_accuracy: 0.9298 - val_loss: 0.2115
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9407 - loss: 0.1585 - val_accuracy: 0.9263 - val_loss: 0.2216
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9398 - loss: 0.1573 - val_accuracy: 0.9242 - val_loss: 0.2247
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9429 - loss: 0.1570 - val_accuracy: 0.9304 - val_loss: 0.2046
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9448 - loss: 0.1528 - val_accuracy: 0.9286 - val_loss: 0.2136
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9435 - loss: 0.1476 - val_accuracy: 0.9232 - val_loss: 0.2417
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9387 - loss: 0.1627 - val_accuracy: 0.9291 - val_loss: 0.2124
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9434 - loss: 0.1488 - val_accuracy: 0.9189 - val_loss: 0.2425
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9442 - loss: 0.1441 - val_accuracy: 0.9204 - val_loss: 0.2464
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9462 - loss: 0.1416 - val_accuracy: 0.9328 - val_loss: 0.2016
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9474 - loss: 0.1419 - val_accuracy: 0.9324 - val_loss: 0.2141
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9466 - loss: 0.1412 - val_accuracy: 0.9332 - val_loss: 0.2059
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9478 - loss: 0.1391 - val_accuracy: 0.9289 - val_loss: 0.2114
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9491 - loss: 0.1356 - val_accuracy: 0.9287 - val_loss: 0.2194
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9492 - loss: 0.1360 - val_accuracy: 0.9330 - val_loss: 0.2027
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9491 - loss: 0.1364 - val_accuracy: 0.9264 - val_loss: 0.2156
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9513 - loss: 0.1338 - val_accuracy: 0.9130 - val_loss: 0.2632
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9506 - loss: 0.1326 - val_accuracy: 0.9309 - val_loss: 0.2124
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9515 - loss: 0.1300 - val_accuracy: 0.9344 - val_loss: 0.2025
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9530 - loss: 0.1285 - val_accuracy: 0.9288 - val_loss: 0.2154
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9526 - loss: 0.1265 - val_accuracy: 0.9341 - val_loss: 0.2076
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9517 - loss: 0.1271 - val_accuracy: 0.9316 - val_loss: 0.2218
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9515 - loss: 0.1282 - val_accuracy: 0.9301 - val_loss: 0.2298
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9534 - loss: 0.1263 - val_accuracy: 0.9262 - val_loss: 0.2324
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9533 - loss: 0.1212 - val_accuracy: 0.9320 - val_loss: 0.2132
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9518 - loss: 0.1250 - val_accuracy: 0.9335 - val_loss: 0.2174
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9542 - loss: 0.1205 - val_accuracy: 0.9318 - val_loss: 0.2222
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9535 - loss: 0.1223 - val_accuracy: 0.9174 - val_loss: 0.2619
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9548 - loss: 0.1183 - val_accuracy: 0.9344 - val_loss: 0.2084
# Train Acc      0.9540166854858398
# Validation Acc 0.9344000220298767
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Class 0 accuracy: 0.9
# Class 1 accuracy: 0.989
# Class 2 accuracy: 0.9
# Class 3 accuracy: 0.926
# Class 4 accuracy: 0.932
# Class 5 accuracy: 0.99
# Class 6 accuracy: 0.769
# Class 7 accuracy: 0.983
# Class 8 accuracy: 0.992
# Class 9 accuracy: 0.963
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9351 - loss: 0.2123
# Test loss   0.20838885009288788
# Test metric 0.9344000220298767
