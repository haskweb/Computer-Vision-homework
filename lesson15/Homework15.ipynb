# %%
# !python --version
# !pip install pixellib
# !ls /usr/local/lib/python3.10/dist-packages/pixellib/
# Out:
# Python 3.10.12
# Requirement already satisfied: pixellib in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pixellib) (11.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.24.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from pixellib) (4.9.0.80)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.8.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.4.0)
# Requirement already satisfied: labelme2coco in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.2.6)
# Requirement already satisfied: imantics in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.12)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.0.11)
# Requirement already satisfied: pyQt5 in /usr/local/lib/python3.10/dist-packages (from pixellib) (5.15.11)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.5.post20221221)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.10)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from pixellib) (2.3.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.1.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from pixellib) (2.5.0)
# Requirement already satisfied: yacs in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pixellib) (4.66.6)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pixellib) (1.0.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (from pixellib) (3.0.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.10/dist-packages (from pixellib) (0.6)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.10/dist-packages (from pixellib) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from pixellib) (24.10.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->pixellib) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore->pixellib) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pixellib) (6.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->pixellib) (3.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from imantics->pixellib) (5.3.0)
# Requirement already satisfied: xmljson in /usr/local/lib/python3.10/dist-packages (from imantics->pixellib) (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (1.13.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (2.36.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug->pixellib) (2.0.6)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pixellib) (0.4)
# Requirement already satisfied: sahi>=0.8.19 in /usr/local/lib/python3.10/dist-packages (from labelme2coco->pixellib) (0.11.19)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from labelme2coco->pixellib) (4.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pixellib) (2.8.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /usr/local/lib/python3.10/dist-packages (from pyQt5->pixellib) (12.16.1)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /usr/local/lib/python3.10/dist-packages (from pyQt5->pixellib) (5.15.15)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.22.3)
# Requirement already satisfied: pybboxes==0.1.6 in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.1.6)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (0.7.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (3.1.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2024.8.30)
# custom_train  __init__.py  instance  __pycache__  semantic  torchbackend  tune_bg

# %%
import os
import fileinput

# Define the path to the file that needs to be modified
FILE_PATH = "/usr/local/lib/python3.10/dist-packages/pixellib/semantic/deeplab.py"

# Define the old and new strings that need to be replaced
OLD_STRING = "tensorflow.python.keras"
NEW_STRING = "tensorflow.keras"

# Use fileinput to replace the old string with the new string in the file
for line in fileinput.input(FILE_PATH, inplace=True):
    print(line.replace(OLD_STRING, NEW_STRING), end='')

# Define the old and new strings that need to be replaced
# This handles model loading errors
OLD_STRING = "tensorflow.keras.utils.layer_utils import get_source_inputs"
NEW_STRING = "tensorflow.python.keras.utils.layer_utils import get_source_inputs"

# Use fileinput to replace the old string with the new string in the file
for line in fileinput.input(FILE_PATH, inplace=True):
    print(line.replace(OLD_STRING, NEW_STRING), end='')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)

cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# Data normalization
x_train = x_train/255
x_test = x_test/255

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])

    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
# Out:
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8287 - loss: 0.4859 - val_accuracy: 0.8877 - val_loss: 0.3173
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9043 - loss: 0.2696 - val_accuracy: 0.8919 - val_loss: 0.3022
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9208 - loss: 0.2220 - val_accuracy: 0.8943 - val_loss: 0.3089
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9320 - loss: 0.1904 - val_accuracy: 0.8977 - val_loss: 0.3181
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9406 - loss: 0.1645 - val_accuracy: 0.8922 - val_loss: 0.3434
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9472 - loss: 0.1461 - val_accuracy: 0.8942 - val_loss: 0.3629
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9556 - loss: 0.1243 - val_accuracy: 0.8913 - val_loss: 0.3893
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9627 - loss: 0.1075 - val_accuracy: 0.8878 - val_loss: 0.4351
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9639 - loss: 0.1014 - val_accuracy: 0.8892 - val_loss: 0.4543
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9682 - loss: 0.0915 - val_accuracy: 0.8823 - val_loss: 0.5042
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9706 - loss: 0.0839 - val_accuracy: 0.8831 - val_loss: 0.5270
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9737 - loss: 0.0764 - val_accuracy: 0.8824 - val_loss: 0.5536
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9758 - loss: 0.0688 - val_accuracy: 0.8834 - val_loss: 0.6072
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9783 - loss: 0.0600 - val_accuracy: 0.8768 - val_loss: 0.6549
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9780 - loss: 0.0590 - val_accuracy: 0.8832 - val_loss: 0.6640
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9794 - loss: 0.0549 - val_accuracy: 0.8763 - val_loss: 0.7203
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9796 - loss: 0.0541 - val_accuracy: 0.8817 - val_loss: 0.7085
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9829 - loss: 0.0470 - val_accuracy: 0.8812 - val_loss: 0.7360
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9815 - loss: 0.0505 - val_accuracy: 0.8795 - val_loss: 0.7747
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9858 - loss: 0.0403 - val_accuracy: 0.8810 - val_loss: 0.7827
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9862 - loss: 0.0416 - val_accuracy: 0.8760 - val_loss: 0.8219
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9863 - loss: 0.0385 - val_accuracy: 0.8800 - val_loss: 0.8415
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9869 - loss: 0.0382 - val_accuracy: 0.8806 - val_loss: 0.8826
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9844 - loss: 0.0439 - val_accuracy: 0.8806 - val_loss: 0.8551
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9851 - loss: 0.0403 - val_accuracy: 0.8790 - val_loss: 0.8777
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9884 - loss: 0.0318 - val_accuracy: 0.8727 - val_loss: 0.9526
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9896 - loss: 0.0291 - val_accuracy: 0.8769 - val_loss: 0.9565
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9891 - loss: 0.0311 - val_accuracy: 0.8771 - val_loss: 0.9726
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9892 - loss: 0.0294 - val_accuracy: 0.8814 - val_loss: 0.9825
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9889 - loss: 0.0298 - val_accuracy: 0.8762 - val_loss: 1.0305
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9890 - loss: 0.0302 - val_accuracy: 0.8760 - val_loss: 1.0581
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9886 - loss: 0.0308 - val_accuracy: 0.8778 - val_loss: 1.0653
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9897 - loss: 0.0290 - val_accuracy: 0.8799 - val_loss: 1.0887
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9900 - loss: 0.0271 - val_accuracy: 0.8812 - val_loss: 1.0803
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9895 - loss: 0.0280 - val_accuracy: 0.8755 - val_loss: 1.1450
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9920 - loss: 0.0249 - val_accuracy: 0.8782 - val_loss: 1.1218
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9917 - loss: 0.0231 - val_accuracy: 0.8827 - val_loss: 1.1160
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9914 - loss: 0.0244 - val_accuracy: 0.8813 - val_loss: 1.1350
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9916 - loss: 0.0242 - val_accuracy: 0.8800 - val_loss: 1.1183
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9921 - loss: 0.0215 - val_accuracy: 0.8800 - val_loss: 1.1610
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9928 - loss: 0.0223 - val_accuracy: 0.8746 - val_loss: 1.2156
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9919 - loss: 0.0238 - val_accuracy: 0.8788 - val_loss: 1.2455
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9926 - loss: 0.0227 - val_accuracy: 0.8800 - val_loss: 1.2686
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9934 - loss: 0.0200 - val_accuracy: 0.8771 - val_loss: 1.2265
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9923 - loss: 0.0213 - val_accuracy: 0.8789 - val_loss: 1.2855
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9929 - loss: 0.0198 - val_accuracy: 0.8726 - val_loss: 1.3058
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9927 - loss: 0.0194 - val_accuracy: 0.8795 - val_loss: 1.2776
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9938 - loss: 0.0170 - val_accuracy: 0.8778 - val_loss: 1.3259
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9914 - loss: 0.0258 - val_accuracy: 0.8802 - val_loss: 1.2463
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9933 - loss: 0.0197 - val_accuracy: 0.8782 - val_loss: 1.3316

# %%
plot_history(history)


# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Train Acc      0.993316650390625
# Validation Acc 0.8781999945640564
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Dropout(0.25)(net)

net = Flatten()(net)
net = Dense(128, activation='relu')(net)
net = BatchNormalization()(net)
net = Dropout(0.5)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

plot_history(history)


# Compute the labels and the predictions as sparse values
y_true = y_test
y_pred = model.predict(x_test).argmax(axis=-1)

# Compute and print the accuracy for each class
for class_id in range(num_classes):
    acc = np.mean(y_pred[y_true == class_id] == class_id)
    print(f'Class {class_id} accuracy: {acc}')

# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)          │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_10 (Flatten)                 │ (None, 3136)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 128)                 │         401,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 422,538 (1.61 MB)
#  Trainable params: 422,090 (1.61 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.7825 - loss: 0.6453 - val_accuracy: 0.8796 - val_loss: 0.3334
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8805 - loss: 0.3382 - val_accuracy: 0.8975 - val_loss: 0.2807
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8926 - loss: 0.2977 - val_accuracy: 0.9064 - val_loss: 0.2551
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9024 - loss: 0.2724 - val_accuracy: 0.8915 - val_loss: 0.2977
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9074 - loss: 0.2537 - val_accuracy: 0.9013 - val_loss: 0.2632
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9098 - loss: 0.2461 - val_accuracy: 0.9118 - val_loss: 0.2416
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9141 - loss: 0.2380 - val_accuracy: 0.9096 - val_loss: 0.2517
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9172 - loss: 0.2267 - val_accuracy: 0.9180 - val_loss: 0.2292
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9202 - loss: 0.2187 - val_accuracy: 0.9163 - val_loss: 0.2361
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9228 - loss: 0.2107 - val_accuracy: 0.9113 - val_loss: 0.2430
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9219 - loss: 0.2097 - val_accuracy: 0.9207 - val_loss: 0.2285
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9274 - loss: 0.1983 - val_accuracy: 0.9234 - val_loss: 0.2203
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9267 - loss: 0.1974 - val_accuracy: 0.9207 - val_loss: 0.2287
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9296 - loss: 0.1899 - val_accuracy: 0.9222 - val_loss: 0.2313
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9313 - loss: 0.1890 - val_accuracy: 0.9043 - val_loss: 0.2806
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9321 - loss: 0.1835 - val_accuracy: 0.9213 - val_loss: 0.2307
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9321 - loss: 0.1828 - val_accuracy: 0.9257 - val_loss: 0.2135
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9344 - loss: 0.1770 - val_accuracy: 0.9233 - val_loss: 0.2310
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9342 - loss: 0.1761 - val_accuracy: 0.9272 - val_loss: 0.2139
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9369 - loss: 0.1726 - val_accuracy: 0.9288 - val_loss: 0.2084
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9368 - loss: 0.1714 - val_accuracy: 0.9267 - val_loss: 0.2152
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9381 - loss: 0.1656 - val_accuracy: 0.9028 - val_loss: 0.2792
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9379 - loss: 0.1626 - val_accuracy: 0.9276 - val_loss: 0.2148
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9425 - loss: 0.1567 - val_accuracy: 0.9315 - val_loss: 0.2144
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9378 - loss: 0.1627 - val_accuracy: 0.9278 - val_loss: 0.2148
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9414 - loss: 0.1566 - val_accuracy: 0.9226 - val_loss: 0.2370
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9411 - loss: 0.1554 - val_accuracy: 0.9272 - val_loss: 0.2168
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9419 - loss: 0.1528 - val_accuracy: 0.9314 - val_loss: 0.2069
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9440 - loss: 0.1505 - val_accuracy: 0.9099 - val_loss: 0.2741
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9429 - loss: 0.1489 - val_accuracy: 0.9292 - val_loss: 0.2128
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9444 - loss: 0.1455 - val_accuracy: 0.9262 - val_loss: 0.2200
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9472 - loss: 0.1420 - val_accuracy: 0.9293 - val_loss: 0.2167
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9466 - loss: 0.1447 - val_accuracy: 0.9295 - val_loss: 0.2155
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9469 - loss: 0.1439 - val_accuracy: 0.9257 - val_loss: 0.2301
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9454 - loss: 0.1419 - val_accuracy: 0.9267 - val_loss: 0.2305
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9494 - loss: 0.1356 - val_accuracy: 0.9134 - val_loss: 0.2615
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9484 - loss: 0.1361 - val_accuracy: 0.9242 - val_loss: 0.2326
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9489 - loss: 0.1364 - val_accuracy: 0.9131 - val_loss: 0.2680
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9469 - loss: 0.1416 - val_accuracy: 0.9311 - val_loss: 0.2150
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9504 - loss: 0.1312 - val_accuracy: 0.9296 - val_loss: 0.2178
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9496 - loss: 0.1338 - val_accuracy: 0.9305 - val_loss: 0.2096
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9522 - loss: 0.1306 - val_accuracy: 0.9320 - val_loss: 0.2140
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9522 - loss: 0.1310 - val_accuracy: 0.9093 - val_loss: 0.2960
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9516 - loss: 0.1290 - val_accuracy: 0.9343 - val_loss: 0.2113
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9532 - loss: 0.1262 - val_accuracy: 0.9294 - val_loss: 0.2238
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9520 - loss: 0.1276 - val_accuracy: 0.9313 - val_loss: 0.2100
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9508 - loss: 0.1291 - val_accuracy: 0.9234 - val_loss: 0.2441
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9519 - loss: 0.1265 - val_accuracy: 0.9262 - val_loss: 0.2377
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9522 - loss: 0.1251 - val_accuracy: 0.9335 - val_loss: 0.2095
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9536 - loss: 0.1229 - val_accuracy: 0.9312 - val_loss: 0.2150
# Train Acc      0.9537500143051147
# Validation Acc 0.9312000274658203
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Class 0 accuracy: 0.899
# Class 1 accuracy: 0.99
# Class 2 accuracy: 0.892
# Class 3 accuracy: 0.928
# Class 4 accuracy: 0.892
# Class 5 accuracy: 0.981
# Class 6 accuracy: 0.792
# Class 7 accuracy: 0.988
# Class 8 accuracy: 0.987
# Class 9 accuracy: 0.963
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9276 - loss: 0.2281
# Test loss   0.21500264108181
# Test metric 0.9312000274658203

# %%
# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = np.random.randint(0, x_test.shape[0])
    # Show the results
    plt.subplot(3, 5, ii+1)
    plt.imshow(x_test[idx, ...], cmap='gray')
    plt.title(f'True: {y_test[idx]} | Pred: {y_pred[idx]}')
    plt.axis('off')

plt.show()
