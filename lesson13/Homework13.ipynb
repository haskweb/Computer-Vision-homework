# %%
import os
import cv2
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Load the training labels
root = '/home/hask/Project/cv_homework/lesson13/data' # Path to the dataset location, e.g., '/data/janko/dataset/GTSRB'
data = pd.read_csv(os.path.join(root, 'Train.csv'))

# Number of training samples (amount of samples in data)
num_samples = len(data)

# Show random data samples
for ii in range(15):
    # Get random index
    idx = np.random.randint(0, num_samples)
    # Load image
    img = cv2.imread(os.path.join(root, data.iloc[idx]['Path']))
    # Convert image to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Show image
    plt.subplot(3,5,ii+1)
    plt.imshow(img)
    plt.title(data.iloc[idx]['ClassId'])
    plt.axis('off')

plt.show()

# Inspect the dataset by computing and plotting the per-class histogram
# Extract class identifiers
ids = data['ClassId']

from collections import Counter
hist = Counter(ids)

plt.bar(hist.keys(), hist.values())
plt.grid(True)
plt.xlabel('Traffic Sign ID')
plt.ylabel('Counts')
plt.show()

# %%
1. Do you consider the dataset to be balanced? If so, why? If not, why?
  - The dataset is considered balanced if each class has an approximately equal number of samples. 
    This means that the height of the bars in histogram should be roughly the same across all classes.
  - If significant variations in the bar heights, the dataset is not balanced.

2. Are there any classes that are (significantly) over-represented or under-represented?
  - Classes that have much taller bars are over-represented, meaning they have more samples than others.
  - Classes with much shorter bars are under-represented, meaning they have fewer samples than others.
