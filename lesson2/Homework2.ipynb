# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

img = cv2.imread('../data/test.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

rows, cols, chanels = img.shape

b, g, r = cv2.split(img)

# Compute the mean values for all three colour channels (red, green, blue)
mean_r = np.mean(r)
mean_g = np.mean(g)
mean_b = np.mean(b)

# Compute the coefficients kr, kg, kb
kr = (mean_b * kb)/mean_r
kg = (mean_b * kb)/mean_g
kb = 1

balanced = np.zeros_like(img)
# Apply color balancing and generate the balanced image
balanced[:, :, 0] = cv2.multiply(img[:, :, 0], kb)
balanced[:, :, 1] = cv2.multiply(img[:, :, 1], kg)
balanced[:, :, 2] = cv2.multiply(img[:, :, 2], kr)

# Show the original and the balanced image side by side
plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(balanced)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f133a242a50>)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

img = cv2.imread('../data/test.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Load your image
img = cv2.imread('/home/hask/Project/test.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

b, g, r = cv2.split(img)
# Compute the maximum values for all three colour channels (red, green, blue)
max_r = np.max(r)
max_g = np.max(g)
max_b = np.max(b)

balanced = np.zeros_like(img)
balanced[:, :, 0] = (b / max_b) * 255
balanced[:, :, 1] = (g / max_g) * 255
balanced[:, :, 2] = (r / max_r) * 255

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(balanced)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f133a3a5e50>)
